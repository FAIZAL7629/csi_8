# %%
# 📌 SECTION 1: Install Dependencies
# !pip install openai faiss-cpu sentence-transformers pandas numpy --quiet

# 📌 SECTION 2: Import Libraries
import openai
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss

# 📌 SECTION 3: Load Dataset (Upload Manually)
from google.colab import files
uploaded = files.upload()

# Assume file is named like this:
csv_path = "Training Dataset.csv"
df = pd.read_csv(csv_path)

# Preview
df.head()
# Out:
#      <input type="file" id="files-f5d0228f-4fbc-4c0d-9695-5269a90f2b73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5d0228f-4fbc-4c0d-9695-5269a90f2b73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# Treat each row as a doc
docs = []
for _, row in df.iterrows():
    text = "\n".join([f"{col}: {row[col]}" for col in df.columns])
    docs.append(text)

# Generate embeddings
embeddings = model.encode(docs, convert_to_numpy=True)

# Index using FAISS
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# %%
# 🔐 Enter your key securely
openai.api_key = input("Paste your OpenAI API key: ")
# Out:
# Paste your OpenAI API key: sk-proj-pfAxolm0qh1Ar3l6C8XA6YhnWtQIvYR3wkDxelAbYM5k-uun-FUA0Tw7yARO6sRCKhFYGu14cbT3BlbkFJmDHpYWokLdjX169-plaYKygwSw01Ba23NbG6TTUBolSUsFIG8TZlH1qeA_V82MyahR6yQO0wQAsk-proj-pfAxolm0qh1Ar3l6C8XA6YhnWtQIvYR3wkDxelAbYM5k-uun-FUA0Tw7yARO6sRCKhFYGu14cbT3BlbkFJmDHpYWokLdjX169-plaYKygwSw01Ba23NbG6TTUBolSUsFIG8TZlH1qeA_V82MyahR6yQO0wQA
# Paste your OpenAI API key: sk-proj-pfAxolm0qh1Ar3l6C8XA6YhnWtQIvYR3wkDxelAbYM5k-uun-FUA0Tw7yARO6sRCKhFYGu14cbT3BlbkFJmDHpYWokLdjX169-plaYKygwSw01Ba23NbG6TTUBolSUsFIG8TZlH1qeA_V82MyahR6yQO0wQAsk-proj-pfAxolm0qh1Ar3l6C8XA6YhnWtQIvYR3wkDxelAbYM5k-uun-FUA0Tw7yARO6sRCKhFYGu14cbT3BlbkFJmDHpYWokLdjX169-plaYKygwSw01Ba23NbG6TTUBolSUsFIG8TZlH1qeA_V82MyahR6yQO0wQA

# %%
# !pip install openai==0.28 --quiet

# %%
import openai
from openai import OpenAI

client = OpenAI(api_key=openai.api_key)

def generate_answer_with_openai(context, query):
    system_prompt = "You are a helpful assistant that answers questions using loan dataset insights."
    user_prompt = f"""
Use the following context to answer the question:

Context:
{context}

Question: {query}
Answer:"""

    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            temperature=0.2,
            max_tokens=300
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {e}"

# %%
# !pip install openai==0.28 --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.9 MB/s eta 0:00:00

# %%
pip install openai==0.28

# %%
while True:
    query = input("\nAsk a loan-related question (or 'exit' to stop): ")
    if query.lower() == 'exit':
        break
    top_docs = retrieve_top_docs(query)
    context = "\n\n".join(top_docs)
    answer = generate_answer_with_openai(context, query)
    print(f"\n📘 Answer:\n{answer}")
# Out:
# Ask a loan-related question (or 'exit' to stop): Does credit history matter?
#
# 📘 Answer:
# Error: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# Ask a loan-related question (or 'exit' to stop): fuck you
#
# 📘 Answer:
# Error: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
